# %%
'''
    Grabing the data from the Browser
    
    Rules:
    
        --> Always try to get permission before scraping!!
    
    Limitation:
    
        --> In general every website is unique which means every scraping script is unique
        --> A slight change or update to a website may break your web scraping script.
'''
# Out:
# '\n    Grabing the data from the Browser\n    \n    Rules:\n    \n        --> Always try to get permission before scraping!!\n    \n    Limitation:\n    \n        --> In general every website is unique which means every scraping script is unique\n        --> A slight change or update to a website may break your web scraping script.\n'

# %%
import requests

# %%
import bs4

# %%
result = requests.get("https://en.wikipedia.org/wiki/Jonas_Salk")

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Jonas Salk - Wikipedia</title>\n<script>document.documentElement.className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled";(function(){var cookie=document.cookie.ma
# ...

# %%
# lxml identifies all the tags and helps to format correct htmlfile
soup = bs4.BeautifulSoup(result.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Jonas Salk - Wikipedia</title>
# ...

# %%
title_list = soup.select('title')

# %%
title_list[0].getText()
# Out:
# 'Jonas Salk - Wikipedia'

# %%
## Grabing all the classes in website

soup.select('div')
# Out:
# [<div class="mw-page-container">
#  <a class="mw-jump-link" href="#bodyContent">Jump to content</a>
#  <div class="mw-page-container-inner">
#  <input class="mw-checkbox-hack-checkbox" id="mw-sidebar-checkbox" type="checkbox"/>
#  <header class="mw-header mw-ui-icon-flush-left mw-ui-icon-flush-right">
#  <div class="vector-header-start">
#  <label aria-controls="mw-panel" class="mw-checkbox-hack-button mw-ui-icon mw-ui-button mw-ui-quiet mw-ui-icon-element mw-ui-icon-flush-right" data-event-name="ui.sidebar" for="mw-sidebar-checkbox" id="mw-sidebar-button" role="button" tabindex="0" title="Main menu">
#  <span>Toggle sidebar</span>
#  </label>
#  <a class="mw-logo" href="/wiki/Main_Page">
#  <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>
#  <span class="mw-logo-container">
# ...

# %%
soup.select('.vector-menu-content')
# Out:
# [<div class="vector-menu-content">
#  <ul class="vector-menu-content-list"><li class="user-links-collapsible-item mw-list-item" id="pt-createaccount-2"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Jonas+Salk" title="You are encouraged to create an account and log in; however, it is not mandatory"><span>Create account</span></a></li><li class="user-links-collapsible-item mw-list-item" id="pt-login-2"><a accesskey="o" href="/w/index.php?title=Special:UserLogin&amp;returnto=Jonas+Salk" title="You're encouraged to log in; however, it's not mandatory. [o]"><span>Log in</span></a></li></ul>
#  </div>,
#  <div class="vector-menu-content vector-dropdown-content">
#  <div class="vector-menu mw-portlet mw-portlet-personal user-links-collapsible-item" id="p-personal" title="User menu">
#  <div class="vector-menu-content">
# ...

# %%
soup.select('div span')
# Out:
# [<span>Toggle sidebar</span>,
#  <span class="mw-logo-container">
#  <img alt="Wikipedia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;"/>
#  <img alt="The Free Encyclopedia" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" style="width: 7.3125em; height: 0.8125em;" width="117"/>
#  </span>,
#  <span>Search</span>,
#  <span>Create account</span>,
#  <span>Log in</span>,
#  <span class="vector-menu-heading-label">Personal tools</span>,
#  <span class="mw-ui-icon mw-ui-icon-userAdd mw-ui-icon-wikimedia-userAdd"></span>,
#  <span>Create account</span>,
#  <span class="mw-ui-icon mw-ui-icon-logIn mw-ui-icon-wikimedia-logIn"></span>,
#  <span>Log in</span>,
#  <span>learn more</span>,
#  <span>Contributions</span>,
#  <span>Talk</span>,
#  <span class="vector-menu-heading-label">Navigation</span>,
#  <span>Main page</span>,
#  <span>Contents</span>,
# ...

# %%
soup.select('div span ')
# Out:
# []

# %%
res = requests.get("https://www.instagram.com/kritisanon/?hl=en")

# %%
soup = bs4.BeautifulSoup(res.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.select('._a3wf _-kb.segoe')
# Out:
# []

# %%
soup.select('.aagw')
# Out:
# []

# %%
soup.select('body div')
# Out:
# [<div id="splash-screen" style="position:fixed;z-index:100;background:#fff;top:0;left:0;width:100%;height:100%"><style nonce="2HY6CmLu" type="text/css">html{overflow-y:scroll!important}</style><img height="80px" src="data:image/png;base64,..." style="position:absolute;top:50%;left:50%;margin:-40px 0 0 -40px" width="80px"/><span style="position:absolute;bottom:32px;left:50%;margin:-36px 0 0 -36px;"><img height="37px" src="data:image/png;base64,..." width="72px"/></span></div>,
#  <div id="mount_0_0_3F"></div>]

# %%
res = requests.get('https://en.wikipedia.org/wiki/Kriti_Sanon')

# %%
soup = bs4.BeautifulSoup(res.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Kriti Sanon - Wikipedia</title>
# ...

# %%
image = soup.select(".infobox-image")
image[0]
kriti_image1 = requests.get("https://upload.wikimedia.org/wikipedia/commons/thumb/c/c0/Kriti_Sanon_snapped_promoting_%27Arjun_Patiala%27_on_sets_of_%27Dance_India_Dance%27_%283%29_%28cropped%29.jpg/220px-Kriti_Sanon_snapped_promoting_%27Arjun_Patiala%27_on_sets_of_%27Dance_India_Dance%27_%283%29_%28cropped%29.jpg")
f = open('kriti_sanon_image2.jpg', 'wb')
f.write(kriti_image1.content)
f.close
# Out:
# <function BufferedWriter.close>

# %%
images_list = soup.select('.thumbimage')

# %%
images_list
# Out:
# [<img class="thumbimage" data-file-height="672" data-file-width="512" decoding="async" height="223" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg/170px-Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg/255px-Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg/340px-Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg 2x" width="170"/>,
# ...

# %%
image1 = images_list[0]
image1
# Out:
# <img class="thumbimage" data-file-height="672" data-file-width="512" decoding="async" height="223" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg/170px-Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg/255px-Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg/340px-Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg 2x" width="170"/>

# %%
type(image1)
# Out:
# bs4.element.Tag

# %% [markdown]
# <img src= "//upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg/170px-Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg">

# %%
kriti_sanon_image = requests.get("https://upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg/170px-Kriti_Sanon_at_the_launch_of_%27Whistle_Baja%27_song_from_%27Heropanti%27.jpg")

# %%
f = open('kriti_sanon.jpg','wb')

# %%
f.write(kriti_sanon_image.content)
# Out:
# 11613

# %%
f.close()
